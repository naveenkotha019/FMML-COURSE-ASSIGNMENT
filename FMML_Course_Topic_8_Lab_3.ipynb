# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkotha019/FMML-COURSE-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-06 18:06:13--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   161MB/s    in 0.4s
#
# 2023-05-06 18:06:14 (161 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6244   1610.03713v1  The goal of semi-supervised learning is to imp...  stat
# 21480  1803.02808v1  Ontologies are critical sources of semantic in...    cs
# 17964  cs/9805101v1  In this paper we re-investigate windowing for ...    cs
# 28431  1706.06347v1  Finding optimal data for inpainting is a key p...    cs
# 17154  1709.00094v1  Different theories posit different sources for...    cs
# ...             ...                                                ...   ...
# 34774  1802.06079v1  Automatic phylogenetic inference plays an incr...    cs
# 22203  1507.05870v2  In this paper, we consider a statistical probl...  stat
# 7138   1710.07739v3  Recent breakthroughs in computer vision make u...    cs
# 17521  1711.09824v1  In this paper, we aim to reveal the impact of ...    cs
# 30094  1711.06787v1  Single image dehazing is an important low-leve...    cs
#
#                                                    title  year  \
# 6244   Optimistic Semi-supervised Least Squares Class...  2016
# 21480  OntoWind: An Improved and Extended Wind Energy...  2018
# 17964                              Integrative Windowing  1998
# 28431  Clustering-Based Quantisation for PDE-Based Im...  2017
# 17154  Linguistic Reflexes of Well-Being and Happines...  2017
# ...                                                  ...   ...
# 34774  Global-scale phylogenetic linguistic inference...  2018
# 22203  A statistical perspective of sampling scores f...  2015
# 7138   Learning Discrete Weights Using the Local Repa...  2017
# 17521  Lexical-semantic resources: yet powerful resou...  2017
# 30094  Learning Aggregated Transmission Propagation N...  2017
#
#                                                 keywords
# 6244   [supervised, supervised, classifiers, addition...
# 21480  [ontologies, information, application, ontolog...
# 17964  [investigate, windowing, algorithms, windowing...
# 28431  [inpainting, differential, compression, recons...
# 17154  [different, different, happiness, appraisal, e...
# ...                                                  ...
# 34774  [automatic, phylogenetic, inference, increasin...
# 22203  [statistical, approximating, importance, distr...
# 7138   [breakthroughs, utilizing, substantial, applic...
# 17521  [resources, particular, disambiguation, catego...
# 30094  [important, applications, researches, investig...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6244     [supervised, supervised, classifiers, addition...
# 21480    [ontologies, information, application, ontolog...
# 17964    [investigate, windowing, algorithms, windowing...
# 28431    [inpainting, differential, compression, recons...
# 17154    [different, different, happiness, appraisal, e...
#                                ...
# 10615    [motivated, predictive, analytics, healthcare,...
# 21744    [dimensionality, reduction, techniques, introd...
# 32487    [comparison, sensitive, difference, classifica...
# 13068    [significant, connected, graphical, structured...
# 7192     [bandlimited, objective, prescribed, cardinali...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8856 words.
# Out of those 4558 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5e9bcaa5-9636-4791-9f39-6b8e7440060f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e9bcaa5-9636-4791-9f39-6b8e7440060f")) {                    Plotly.newPlot(                        "5e9bcaa5-9636-4791-9f39-6b8e7440060f",                        [{"x":["difficulty","partially","unlabeled","classifiers","benchmark","coordinate","additional","supervised","behaviour","resulting","classifier","functions","outperforms","typically","objective","different","classification","corresponding","optimistic","applications","previously","significant","information","usability","attributes","renewable","available","instances","presented","engineering","application","implemented","contribution","informatics","regarding","restructured","electrical","ontologies","independently","artificial","substantial","experimental","discovered","experiments","algorithm","integrative","iterations","subsequent","furthermore","integrating","algorithms","investigate","inpainting","surprisingly","performance","locations","approaches","understood","efficient","correlated","significantly","increased","impacting","mandatory","compression","challenging","histogram","translate","differential","reconstruction","strategies","clustering","assessment","emotional","linguistic","experience","happiness","competence","connection","empirically","resources","theoretical","recurrent","determination","descriptions","responses","predicting","predictions","behavioral","reduction","societies","predictive","industrial","percentage","organizing","collective","measurements","indicators","causality","presidential","hypothesis","economics","inclusion","comparing","extension","individual","dimensions","diagnostic","neuroscience","competitively","architectures","progressively","reasoning","cognitive","addresses","psychology","generalize","developed","configurable","tradition","intelligence","architecture","preliminary","demonstrate","additionally","interpretable","comparable","dictionaries","improving","vocabulary","acceleration","multilingual","requirement","especially","improvements","motivates","comparison","conducted","translation","introducing","unfortunately","accelerated","availability","languages","wikipedia","statistical","computing","methodology","constructed","neologisms","dependent","extracted","numerical","corrupted","quantities","independent","magnitudes","developing","retrieval","accomplished","statistically","computationally","measurement","respectively","arbitrary","effectiveness","logarithmic","quadratic","initialization","adversarially","situation","nonconvex","investigates","concentration","truncated","robustify","corrected","recognition","parameters","predictor","recognizers","automatically","incorporation","evaluation","nonlinear","prediction","regression","transferable","comparative","capability","descriptors","equivalent","estimation","dimensional","estimates","structured","generalization","histograms","generative","binarycategorical"],"y":[45,41,52,103,187,28,116,194,30,146,159,220,268,103,163,782,532,146,6,443,93,247,676,4,72,3,311,106,186,58,245,106,62,4,53,2,3,22,41,155,52,399,26,573,824,2,33,22,164,38,583,152,13,30,885,36,436,29,427,29,261,35,4,4,47,270,22,13,26,113,84,158,40,23,65,43,6,2,41,74,83,149,137,13,36,26,82,81,17,88,4,44,26,13,14,9,40,10,10,4,57,6,9,67,87,121,44,19,13,4,139,7,142,61,48,16,59,206,3,1,95,262,38,557,50,28,93,17,109,38,16,19,32,123,92,5,140,81,91,45,37,17,22,85,14,178,148,61,61,2,72,118,75,20,10,121,1,55,104,13,14,92,31,96,93,234,16,34,28,5,34,8,31,19,6,2,9,389,240,14,2,198,5,252,58,228,130,4,28,53,43,63,204,178,72,103,111,4,110,0],"type":"bar"},{"x":["difficulty","partially","unlabeled","classifiers","benchmark","coordinate","additional","supe ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4558,), (4558, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gaussian</span> <span style=''>Process</span> <span style=''>Models</span> <span style=''>for</span> <span style=''>HRTF</span> <span style=''>based</span> <span style=''>Sound</span> <span style=''>Source</span> <span style='background-color:rgba(0, 255, 0, 0.6867469879518073);'>Localization</span> <span style=''>and</span> <span style=''>Active</span> <span style=''>Learning</span> <br/><br/><span style=''>From</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>the</span> <span style=''>human</span> <span style=''>ability</span> <span style=''>localize</span> <span style=''>sounds</span> <span style=''>can</span> <span style=''>be</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.4042553191489363);'>parametric</span> <span style=''>and</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.47474747474747475);'>regression</span> <span style=''>problem</span> <span style=''>between</span> <span style=''>binaural</span> <span style=''>spectral</span> <span style=''>features</span> <span style=''>of</span> <span style=''>sound</span> <span style=''>received</span> <span style=''>at</span> <span style=''>the</span> <span style=''>ears</span> <span style=''>(input)</span> <span style=''>and</span> <span style=''>their</span> <span style=''>sound</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directions</span> <span style=''>(output)</span> <span style=''>The</span> <span style=''>input</span> <span style=''>features</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>summarized</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>individuals</span> <span style=''>head</span> <span style=''>related</span> <span style=''>transfer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>(HRTFs)</span> <span style=''>which</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>response</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>listeners</span> <span style=''>eardrum</span> <span style=''>and</span> <span style=''>an</span> <span style=''>external</span> <span style=''>point</span> <span style=''>in</span> <span style=''>3D</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.6799999999999999);'>viewpoints</span> <span style=''>two</span> <span style=''>related</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>how</span> <span style=''>can</span> <span style=''>one</span> <span style=''>achieve</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>sampling</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>for</span> <span style=''>training</span> <span style=''>sound</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.6867469879518073);'>localization</span> <span style=''>(SSL)</span> <span style=''>models</span> <span style=''>and</span> <span style=''>how</span> <span style=''>can</span> <span style=''>SSL</span> <span style=''>models</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>subjects</span> <span style=''>HRTFs</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Kernel</span> <span style=''>Density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dynamical</span> <span style=''>Systems</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>problem</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>certain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>admit</span> <span style=''>a</span> <span style=''>unique</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>Lebesgue</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Observations</span> <span style=''>drawn</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>and</span> <span style=''>moreover</span> <span style=''>usual</span> <span style=''>mixing</span> <span style=''>concepts</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measuring</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>among</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>employing</span> <span style=''>the</span> <span style=''>mathcalC</span> <span style=''>mixing</span> <span style=''>concept</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>we</span> <span style=''>conduct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>analysis</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>results</span> <span style=''>are</span> <span style=''>as</span> <span style=''>follows</span> <span style=''>First</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>with</span> <span style=''>properly</span> <span style=''>chosen</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bandwidth</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>density</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>under</span> <span style=''>L</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>Second</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style='backgrou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Partial</span> <span style=''>Hessian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Strategies</span> <span style=''>for</span> <span style=''>Fast</span> <span style=''>Learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.34831460674157305);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.32142857142857134);'>Embeddings</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.34292565947242204);'>Stochastic</span> <span style=''>neighbor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>(SNE)</span> <span style=''>and</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.34831460674157305);'>nonlinear</span> <span style=''>manifold</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>achieve</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.38831615120274915);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.38853503184713367);'>representations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3853211009174312);'>similarity</span> <span style=''>data</span> <span style=''>but</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>notoriously</span> <span style=''>slow</span> <span style=''>to</span> <span style=''>train</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>generic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>includes</span> <span style=''>SNE</span> <span style=''>and</span> <span style=''>other</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>study</span> <span style=''>their</span> <span style=''>relation</span> <span style=''>with</span> <span style=''>spectral</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacians</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>define</span> <span style=''>several</span> <span style=''>partial</span> <span style=''>Hessian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterize</span> <span style=''>their</span> <span style=''>global</span> <span style=''>and</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.36599423631123923);'>convergence</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>them</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>We</span> <span style=''>achieve</span> <span style=''>up</span> <span style=''>to</span> <span style=''>two</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>speedup</span> <span style=''>over</span> <span style=''>existing</span> <span style=''>training</span> <span style=''>methods</span> <span style=''>with</span> <span style=''>a</span> <span style=''>strategy</span> <span style=''>(which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>the</span> <span style=''>spectral</span> <span style=''>direction)</span> <span style=''>that</span> <span style=''>adds</span> <span style=''>nearly</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Disaggregation</span> <span style=''>for</span> <span style=''>Real</span> <span style=''>Time</span> <span style=''>Building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Flexibility</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style=''>Energy</span> <span style=''>is</span> <span style=''>a</span> <span style=''>limited</span> <span style=''>resource</span> <span style=''>which</span> <span style=''>has</span> <span style=''>to</span> <span style=''>be</span> <span style=''>managed</span> <span style=''>wisely</span> <span style=''>taking</span> <span style=''>into</span> <span style=''>account</span> <span style=''>both</span> <span style=''>supply</span> <span style=''>demand</span> <span style=''>matching</span> <span style=''>and</span> <span style=''>capacity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>grid</span> <span style=''>One</span> <span style=''>aspect</span> <span style=''>of</span> <span style=''>the</span> <span style=''>smart</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>management</span> <span style=''>at</span> <span style=''>the</span> <span style=''>building</span> <span style=''>level</span> <span style=''>is</span> <span style=''>given</span> <span style=''>by</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>of</span> <span style=''>flexible</span> <span style=''>demand</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disaggregation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>this</span> <span style=''>task</span> <span style=''>Firstly</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disaggregation</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>between</span> <span style=''>four</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>namely</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style=''>k</span> <span style=''>Nearest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Neighbors</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>and</span> <span style=''>AdaBoost</span> <span style=''>Secondly</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Restricted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Boltzmann</span> <span style=''>Machine</span> <span style=''>to</span> <span style='background-color:rgba(255, ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1355206847360913)
# 	processing (0.1080599144079886)
# 	segmentation (0.0723965763195435)
# 	experimental (0.14229671897289586)
# 	detection (0.1144793152639087)
# 	architecture (0.09343794579172611)
# 	information (0.24108416547788872)
# 	different (0.2788873038516405)
# 	convolutional (0.13516405135520684)
# 	recognition (0.13873038516405137)
#
# Some Statistics words are:
# 	algorithm (0.38527054108216435)
# 	stochastic (0.1402805611222445)
# 	statistical (0.1598196392785571)
# 	variables (0.1492985971943888)
# 	theoretical (0.15480961923847694)
# 	estimation (0.18086172344689377)
# 	distribution (0.18837675350701402)
# 	inference (0.19589178356713427)
# 	regression (0.18286573146292584)
# 	dimensional (0.20240480961923848)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="98a238ab-2525-4f13-8128-f11c87f077d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98a238ab-2525-4f13-8128-f11c87f077d7")) {                    Plotly.newPlot(                        "98a238ab-2525-4f13-8128-f11c87f077d7",                        [{"x":["difficulty","partially","unlabeled","classifiers","benchmark","coordinate","additional","supervised","behaviour","resulting","classifier","functions","outperforms","typically","objective","different","classification","corresponding","optimistic","applications","previously","significant","information","usability","attributes","renewable","available","instances","presented","engineering","application","implemented","contribution","informatics","regarding","restructured","electrical","ontologies","independently","artificial","substantial","experimental","discovered","experiments","algorithm","integrative","iterations","subsequent","furthermore","integrating","algorithms","investigate","inpainting","surprisingly","performance","locations","approaches","understood","efficient","correlated","significantly","increased","impacting","mandatory","compression","challenging","histogram","translate","differential","reconstruction","strategies","clustering","assessment","emotional","linguistic","experience","happiness","competence","connection","empirically","resources","theoretical","recurrent","determination","descriptions","responses","predicting","predictions","behavioral","reduction","societies","predictive","industrial","percentage","organizing","collective","measurements","indicators","causality","presidential","hypothesis","economics","inclusion","comparing","extension","individual","dimensions","diagnostic","neuroscience","competitively","architectures","progressively","reasoning","cognitive","addresses","psychology","generalize","developed","configurable","tradition","intelligence","architecture","preliminary","demonstrate","additionally","interpretable","comparable","dictionaries","improving","vocabulary","acceleration","multilingual","requirement","especially","improvements","motivates","comparison","conducted","translation","introducing","unfortunately","accelerated","availability","languages","wikipedia","statistical","computing","methodology","constructed","neologisms","dependent","extracted","numerical","corrupted","quantities","independent","magnitudes","developing","retrieval","accomplished","statistically","computationally","measurement","respectively","arbitrary","effectiveness","logarithmic","quadratic","initialization","adversarially","situation","nonconvex","investigates","concentration","truncated","robustify","corrected","recognition","parameters","predictor","recognizers","automatically","incorporation","evaluation","nonlinear","prediction","regression","transferable","comparative","capability","descriptors","equivalent","estimation","dimensional","estimates","structured","generalization","histograms","generative","binarycategorical","visualized","analogies","distribution","framework","introduce","nonparametric","irrespective","divergence","corollary","continuous","balancing","annealing","conjecture","adversarial","synthetic","automated","relatively","opportunities","demonstrates","technological","curvature","evaluating","important","smoothness","subjective","minimally","predominantly","frameworks","simplicity","development","completion","implement","generalizability","perception","introduced","including","discriminate","scientists","restricted","reasonable","composition","acknowledged","undesirable","originating","qualitative","generating","identified","establish","technique","relations","illustrated","introduces","automatic","challenge","expression","variables","situat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	binarycategorical
# 	exogenous
# 	subpopulations
# 	scleroderma
# 	confounder
# 	eigenspaces
# 	cytometry
# 	replicates
# 	reconstructive
# 	quadrature
# 	straggler
# 	equiangular
# 	distinguishability
# 	spreading
# 	resampled
# 	textitnon
# 	infinitesimal
# 	jackknife
# 	hydrology
# 	resampling
# Some words which never appear in Statistics papers:
# 	ontologies
# 	impacting
# 	mandatory
# 	happiness
# 	competence
# 	societies
# 	psychology
# 	configurable
# 	neologisms
# 	recognizers
# 	acknowledged
# 	acceptability
# 	unacceptable
# 	argumentation
# 	originality
# 	rhetorical
# 	paragraphs
# 	discourse
# 	fuzziness
# 	controllability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0676728633658504e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
